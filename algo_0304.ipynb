# %%
NODE_SPEC = {
    "node-32": {
        "cpu_cores": 32,  # 16 * 2
        "memory_gb": 256,
        "gpu_count": 8,  # NVIDIA Tesla V100 (32G) * 8
        "gpu_memory_gb": 32 * 8,  # Total GPU memory
        "power_active": 4400,  # 2200 * 2
        "power_idle": 3080,    # 70% of active
        "power_standby": 440   # 10% of active
    },
    "node-11": {
        "cpu_cores": 44,  # 22 * 2
        "memory_gb": 512,
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 2200,  # 1100 * 2
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-12": {
        "cpu_cores": 44,  # 22 * 2
        "memory_gb": 512,
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 2200,  # 1100 * 2
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-13": {
        "cpu_cores": 44,  # 22 * 2
        "memory_gb": 512,
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 2200,  # 1100 * 2
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-14": {
        "cpu_cores": 96,  # 24 * 4
        "memory_gb": 512,
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 2200,  # 1100 * 2
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "esxi-31": {
        "cpu_cores": 28,  # 14 * 2
        "memory_gb": 256,
        "gpu_count": 2,   # NVIDIA Tesla V100 (16G) * 2
        "gpu_memory_gb": 16 * 2,  # Total GPU memory
        "power_active": 3200,  # 1600 * 2
        "power_idle": 2240,    # 70% of active
        "power_standby": 320   # 10% of active
    },
    "node-15": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-31
        "gpu_count": 1,   # NVIDIA Tesla V100 (16G) * 1
        "gpu_memory_gb": 16,
        "power_active": 1600,  # Assumed from esxi-31
        "power_idle": 1120,    # 70% of active
        "power_standby": 160   # 10% of active
    },
    "node-16": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-31
        "gpu_count": 1,   # NVIDIA Tesla V100 (16G) * 1
        "gpu_memory_gb": 16,
        "power_active": 1600,  # Assumed from esxi-31
        "power_idle": 1120,    # 70% of active
        "power_standby": 160   # 10% of active
    },
    "node-17": {
        "cpu_cores": 36,  # 18 * 2
        "memory_gb": 256,
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 3200,  # 1600 * 2
        "power_idle": 2240,    # 70% of active
        "power_standby": 320   # 10% of active
    },
    "node-18": {
        "cpu_cores": 36,  # 18 * 2
        "memory_gb": 256,
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 3200,  # 1600 * 2
        "power_idle": 2240,    # 70% of active
        "power_standby": 320   # 10% of active
    },
    "node-19": {
        "cpu_cores": 80,  # 20 * 4
        "memory_gb": 128,
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 6400,  # 1600 * 4
        "power_idle": 4480,    # 70% of active
        "power_standby": 640   # 10% of active
    },
    "esxi-33": {
        "cpu_cores": 36,  # 18 * 2
        "memory_gb": 256,
        "gpu_count": 8,   # NVIDIA GeForce RTX2080Ti * 8
        "gpu_memory_gb": 11 * 8,  # Approx. 11GB per RTX2080Ti
        "power_active": 4400,  # 2200 * 2
        "power_idle": 3080,    # 70% of active
        "power_standby": 440   # 10% of active
    },
    "node-151": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-33
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 2200,  # Assumed from esxi-33
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-152": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-33
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 2200,  # Assumed from esxi-33
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-153": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-33
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 2200,  # Assumed from esxi-33
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-154": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-33
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 2200,  # Assumed from esxi-33
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-155": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-33
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 2200,  # Assumed from esxi-33
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-156": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-33
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 2200,  # Assumed from esxi-33
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-157": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-33
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 2200,  # Assumed from esxi-33
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-158": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-33
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 2200,  # Assumed from esxi-33
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "esxi-34": {
        "cpu_cores": 36,  # 18 * 2
        "memory_gb": 256,
        "gpu_count": 8,   # NVIDIA GeForce RTX2080Ti * 8
        "gpu_memory_gb": 11 * 8,  # Approx. 11GB per RTX2080Ti
        "power_active": 4400,  # 2200 * 2
        "power_idle": 3080,    # 70% of active
        "power_standby": 440   # 10% of active
    },
    "node-161": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-34
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 2200,  # Assumed from esxi-34
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-162": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-34
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 2200,  # Assumed from esxi-34
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-163": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-34
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 2200,  # Assumed from esxi-34
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-164": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-34
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 2200,  # Assumed from esxi-34
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-165": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-34
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 2200,  # Assumed from esxi-34
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-166": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-34
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 2200,  # Assumed from esxi-34
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-167": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-34
        "gpu_count": 0,   # No GPU
        "gpu_memory_gb": 0,
        "power_active": 2200,  # Assumed from esxi-34
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "node-168": {
        "cpu_cores": 4,
        "memory_gb": 256,  # Assumed from esxi-34
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 2200,  # Assumed from esxi-34
        "power_idle": 1540,    # 70% of active
        "power_standby": 220   # 10% of active
    },
    "esxi-35": {
        "cpu_cores": 32,  # 16 * 2
        "memory_gb": 128,
        "gpu_count": 3,   # NVIDIA GeForce RTX2080Ti * 3
        "gpu_memory_gb": 11 * 3,  # Approx. 11GB per RTX2080Ti
        "power_active": 3200,  # 1600 * 2
        "power_idle": 2240,    # 70% of active
        "power_standby": 320   # 10% of active
    },
    "node-141": {
        "cpu_cores": 4,
        "memory_gb": 128,  # Assumed from esxi-35
        "gpu_count": 1,   # NVIDIA GeForce RTX2080Ti * 1
        "gpu_memory_gb": 11,
        "power_active": 1600,  # Assumed from esxi-35
        "power_idle": 1120,    # 70% of active
        "power_standby": 160   # 10% of active
    },
    "esxi-36": {
        "cpu_cores": 32,  # 16 * 2
        "memory_gb": 128,
        "gpu_count": 3,   # NVIDIA GeForce RTX3080 * 3
        "gpu_memory_gb": 12 * 3,  # Approx. 12GB per RTX3080
        "power_active": 2400,  # 2400 * 1
        "power_idle": 1680,    # 70% of active
        "power_standby": 240   # 10% of active
    },
    "node-171": {
        "cpu_cores": 4,
        "memory_gb": 128,  # Assumed from esxi-36
        "gpu_count": 1,   # NVIDIA GeForce RTX3080 * 1
        "gpu_memory_gb": 12,
        "power_active": 2400,  # Assumed from esxi-36
        "power_idle": 1680,    # 70% of active
        "power_standby": 240   # 10% of active
    },
    "node-172": {
        "cpu_cores": 4,
        "memory_gb": 128,  # Assumed from esxi-36
        "gpu_count": 2,   # NVIDIA GeForce RTX3080 * 2
        "gpu_memory_gb": 12 * 2,
        "power_active": 2400,  # Assumed from esxi-36
        "power_idle": 1680,    # 70% of active
        "power_standby": 240   # 10% of active
    },
    "esxi-37": {
        "cpu_cores": 32,  # 16 * 2
        "memory_gb": 128,
        "gpu_count": 3,   # NVIDIA GeForce RTX3080 * 3
        "gpu_memory_gb": 12 * 3,  # Approx. 12GB per RTX3080
        "power_active": 2400,  # 2400 * 1
        "power_idle": 1680,    # 70% of active
        "power_standby": 240   # 10% of active
    }
}

# %%
import pandas as pd
CPU_request_data = pd.read_csv('./data/cpu_request_202501_hourly_node.csv')
PDU_DATA = pd.read_excel('./data/20240722_1231_PDU_DATA.xlsx')

print(CPU_request_data.columns)

# Rename 'node' to 'nodename' in the DataFrame
CPU_request_data.rename(columns={'node': 'nodename'}, inplace=True)

print(CPU_request_data.columns)
# Out:
# Index(['hour', 'node', 'cpu_load', 'cpu_alloc', 'cpu_idle', 'cpu_total',
#        'gpu_power_usage', 'gpu_mem_used', 'gpu_gpu_usage', 'gpu_fan'],
#       dtype='object')
# Index(['hour', 'nodename', 'cpu_load', 'cpu_alloc', 'cpu_idle', 'cpu_total',
#        'gpu_power_usage', 'gpu_mem_used', 'gpu_gpu_usage', 'gpu_fan'],
#       dtype='object')

# %%
CPU_request_data[0:5]
# Out:
#                   hour nodename  cpu_load  cpu_alloc  cpu_idle  cpu_total  \
# 0  2024-11-04 14:00:00  node-14    95.110       95.0       1.0       96.0
# 1  2024-11-04 14:00:00  node-13    44.105       44.0       0.0       44.0
# 2  2024-11-04 14:00:00  node-32    18.680       30.0       2.0       32.0
# 3  2024-11-04 14:00:00  node-19     5.000        5.0      75.0       80.0
# 4  2024-11-04 14:00:00  node-18    28.040       36.0       0.0       36.0
#
#    gpu_power_usage  gpu_mem_used  gpu_gpu_usage  gpu_fan
# 0              NaN           NaN            NaN      NaN
# 1              NaN           NaN            NaN      NaN
# 2          98.1625      7270.375        14.5625      0.0
# 3              NaN           NaN            NaN      NaN
# 4              NaN           NaN            NaN      NaN

# %%
# EAVMAT Scheduling Algorithm
def eavmat_scheduling(nodes: List[Node], workload: pd.DataFrame) -> Dict:
    results = {"energy_consumption": 0, "job_success_rate": 0, "active_hosts": 0}
    total_jobs = 0
    successful_jobs = 0
    
    print("ffffu", nodes, workload)
    
    
    for idx, row in workload.iterrows():
        time = pd.to_datetime(row["hour"])
        cpu_load = row["cpu_load"]
        gpu_power = row["gpu_power_usage"]
        gpu_mem = row["gpu_mem_used"]
        nodename = row["nodename"]
        
        print("nodenamenodename", nodename)

        # Classify jobs into AR, IM, BE for this node
        jobs = classify_jobs(cpu_load, JOB_DISTRIBUTION)
        total_jobs += len(jobs)

        # Get the specific node
        node = next(n for n in nodes if n.name == nodename)
        # next() 函式用來從可迭代對象（例如列表、生成器等）中獲取下一個元素。若沒有更多元素，它會引發 StopIteration 錯誤。
        # 使用 next() 的預設值： 你可以使用 next() 的第二個參數來指定如果沒有匹配的項目時返回一個預設值，這樣就不會引發 StopIteration。例如：
        node = next((n for n in nodes if n.name == nodename), None)

        for job_type, load in jobs:
            scheduled = False
            # Try to schedule on the specific node first (since workload is per node)
            if node.can_handle_job(load, gpu_power, gpu_mem):
                node.cpu_used += load
                if NODE_SPEC[nodename]["gpu_count"] > 0:
                    node.gpu_power_used += gpu_power
                    node.gpu_mem_used += gpu_mem
                node.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                node.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                scheduled = True
                successful_jobs += 1
            else:
                # If this node can't handle, try other active/idle nodes (simplified)
                other_nodes = [n for n in nodes if n.name != nodename and n.state in ["Active", "Idle"]]
                for other_node in sorted(other_nodes, key=lambda x: x.available_time):
                    if other_node.can_handle_job(load, gpu_power, gpu_mem):
                        other_node.cpu_used += load
                        if NODE_SPEC[other_node.name]["gpu_count"] > 0:
                            other_node.gpu_power_used += gpu_power
                            other_node.gpu_mem_used += gpu_mem
                        other_node.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                        other_node.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                        other_node.state = "Active"
                        scheduled = True
                        successful_jobs += 1
                        break

            if not scheduled and job_type in ["AR", "IM"]:
                # Preempt BE job if possible (simplified: assume BE jobs can be preempted on this node or others)
                for target_node in [node] + other_nodes:
                    if target_node.vm_queue and any(j[0] == "BE" for j in target_node.vm_queue):
                        target_node.vm_queue = [j for j in target_node.vm_queue if j[0] != "BE"]
                        target_node.cpu_used += load
                        if NODE_SPEC[target_node.name]["gpu_count"] > 0:
                            target_node.gpu_power_used += gpu_power
                            target_node.gpu_mem_used += gpu_mem
                        target_node.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                        target_node.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                        scheduled = True
                        successful_jobs += 1
                        break

            if not scheduled:
                # Job rejected (e.g., for AR/IM if no resources available)
                continue

    # Calculate energy consumption over 1 hour (60 minutes)
    total_time_minutes = 60
    for node in nodes:
        state_time = total_time_minutes  # Simplified: assume node stays in current state for entire period
        results["energy_consumption"] += node.get_power_consumption() * state_time

    results["job_success_rate"] = (successful_jobs / total_jobs) * 100 if total_jobs > 0 else 0
    results["active_hosts"] = len([n for n in nodes if n.state == "Active"])

    return results

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
from typing import Dict, List, Tuple
import random


# Constants from the paper
JOB_TYPES = ["AR", "IM", "BE"]  # Advance Reservation, Immediate, Best Effort
JOB_DISTRIBUTION = {"AR": 0.2, "IM": 0.3, "BE": 0.5}  # Percentage of each job type
IDLE_THRESHOLD_MINUTES = 30  # I_th
MIN_IDLE_HOSTS = 1

# Function to classify jobs based on resource usage with random distribution
def classify_jobs(cpu_load: float, job_dist: Dict) -> List[Tuple[str, float]]:
    """
    Randomly classify CPU load into AR, IM, and BE jobs based on specified distribution.
    
    Args:
        cpu_load (float): Total CPU load to distribute.
        job_dist (Dict): Distribution of job types, e.g., {"AR": 0.2, "IM": 0.3, "BE": 0.5}.
    
    Returns:
        List[Tuple[str, float]]: List of (job_type, load) tuples with random loads summing to cpu_load.
    """
    if cpu_load <= 0:
        return []  # Return empty list if no load

    # Extract job types and their probabilities
    job_types = list(job_dist.keys())
    probabilities = list(job_dist.values())

    # Generate random loads using multinomial distribution to ensure the sum equals cpu_load
    n_trials = 1000  # Number of trials for finer granularity
    
    """
    print("random_loads = np.random.multinomial", probabilities, n_trials * cpu_load, np.random.multinomial(n_trials, probabilities) / n_trials * cpu_load)
    random_loads = np.random.multinomial [0.2, 0.3, 0.5] 95110.0 [16.1687  27.67701 51.26429]
    random_loads = np.random.multinomial [0.2, 0.3, 0.5] 44105.0 [10.100045 12.834555 21.1704]
    random_loads = np.random.multinomial [0.2, 0.3, 0.5] 105.0 [0.019635 0.03276  0.052605]
    """
    
    random_loads = np.random.multinomial(n_trials, probabilities) / n_trials * cpu_load


    # Create list of (job_type, load) tuples  取 [16.1687  27.67701 51.26429] 的最大值
    jobs = [(job_type, max(0.001, load)) for job_type, load in zip(job_types, random_loads)]  # Avoid zero loads 
    """
    print("zip(job_types, random_loads)", zip(job_types, random_loads), jobs)
    zip(job_types, random_loads) <zip object at 0x1568d4380> [('AR', 0.65464), ('IM', 0.9752799999999999), ('BE', 1.71008)]
    jobsjobs [('AR', 0.65464), ('IM', 0.9752799999999999), ('BE', 1.71008)]
    nodenamenodename node-161
    zip(job_types, random_loads) <zip object at 0x1568d4180> [('AR', 0.8240999999999998), ('IM', 1.1698199999999999), ('BE', 2.02608)]
    """
    
    print("jobsjobs", jobs)
    return jobs

# Node class to manage state and resources
class Node:
    def __init__(self, name: str):
        self.name = name
        self.state = "Idle"  # Start in Idle state
        self.cpu_used = 0
        self.gpu_power_used = 0
        self.gpu_mem_used = 0
        self.vm_queue = []  # List of jobs (VM requests) in queue
        self.last_active_time = None
        self.available_time = 0  # Earliest available time for VMs

    def update_state(self, time_minutes: float, job_load: float = 0):
        if job_load > 0 and self.state in ["Idle", "Standby"]:
            self.state = "Active"
            self.last_active_time = time_minutes
        elif job_load == 0 and self.state == "Active":
            if time_minutes - self.last_active_time > IDLE_THRESHOLD_MINUTES:
                self.state = "Standby"
            else:
                self.state = "Idle"
        self.cpu_used = job_load
        # Update GPU usage if applicable (simplified for now)
        if NODE_SPEC[self.name]["gpu_count"] > 0:
            self.gpu_power_used = job_load * 10  # Placeholder: adjust based on actual GPU load

    def get_power_consumption(self) -> float:
        if self.state == "Active":
            return NODE_SPEC[self.name]["power_active"]
        elif self.state == "Idle":
            return NODE_SPEC[self.name]["power_idle"]
        else:  # Standby
            return NODE_SPEC[self.name]["power_standby"]

    def can_handle_job(self, cpu_load: float, gpu_power: float, gpu_mem: float) -> bool:
        cpu_capacity = NODE_SPEC[self.name]["cpu_cores"] * 100  # Assume 100 units/core
        gpu_capacity = NODE_SPEC[self.name]["gpu_count"] * 100  # Placeholder GPU capacity
        return (self.cpu_used + cpu_load <= cpu_capacity and 
                (NODE_SPEC[self.name]["gpu_count"] == 0 or 
                 (self.gpu_power_used + gpu_power <= gpu_capacity and 
                  self.gpu_mem_used + gpu_mem <= NODE_SPEC[self.name]["gpu_memory_gb"] * 1024)))  # Convert GB to MB
    # 多加的
    def reset_usage(self):
        self.cpu_used = 0
        self.gpu_power_used = 0
        self.gpu_mem_used = 0
        self.vm_queue = []
        self.state = "Idle"
        self.last_active_time = None
        self.available_time = 0

# Scheduling Algorithms
# EAVMAT Scheduling Algorithm
def eavmat_scheduling(nodes: List[Node], workload: pd.DataFrame) -> Dict:
    results = {"energy_consumption": 0, "job_success_rate": 0, "active_hosts": 0}
    total_jobs = 0
    successful_jobs = 0
    
    print("ffffu", nodes, workload)
    
    
    for idx, row in workload.iterrows():
        time = pd.to_datetime(row["hour"])
        cpu_load = row["cpu_load"]
        gpu_power = row["gpu_power_usage"]
        gpu_mem = row["gpu_mem_used"]
        nodename = row["nodename"]
        
        print("nodenamenodename", nodename)

        # Classify jobs into AR, IM, BE for this node
        jobs = classify_jobs(cpu_load, JOB_DISTRIBUTION)
        total_jobs += len(jobs)

        # Get the specific node
        node = next(n for n in nodes if n.name == nodename)
        # next() 函式用來從可迭代對象（例如列表、生成器等）中獲取下一個元素。若沒有更多元素，它會引發 StopIteration 錯誤。
        # 使用 next() 的預設值： 你可以使用 next() 的第二個參數來指定如果沒有匹配的項目時返回一個預設值，這樣就不會引發 StopIteration。例如：
        node = next((n for n in nodes if n.name == nodename), None)

        for job_type, load in jobs:
            scheduled = False
            # Try to schedule on the specific node first (since workload is per node)
            if node.can_handle_job(load, gpu_power, gpu_mem):
                node.cpu_used += load
                if NODE_SPEC[nodename]["gpu_count"] > 0:
                    node.gpu_power_used += gpu_power
                    node.gpu_mem_used += gpu_mem
                node.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                node.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                scheduled = True
                successful_jobs += 1
            else:
                # If this node can't handle, try other active/idle nodes (simplified)
                other_nodes = [n for n in nodes if n.name != nodename and n.state in ["Active", "Idle"]]
                for other_node in sorted(other_nodes, key=lambda x: x.available_time):
                    if other_node.can_handle_job(load, gpu_power, gpu_mem):
                        other_node.cpu_used += load
                        if NODE_SPEC[other_node.name]["gpu_count"] > 0:
                            other_node.gpu_power_used += gpu_power
                            other_node.gpu_mem_used += gpu_mem
                        other_node.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                        other_node.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                        other_node.state = "Active"
                        scheduled = True
                        successful_jobs += 1
                        break

            if not scheduled and job_type in ["AR", "IM"]:
                # Preempt BE job if possible (simplified: assume BE jobs can be preempted on this node or others)
                for target_node in [node] + other_nodes:
                    if target_node.vm_queue and any(j[0] == "BE" for j in target_node.vm_queue):
                        target_node.vm_queue = [j for j in target_node.vm_queue if j[0] != "BE"]
                        target_node.cpu_used += load
                        if NODE_SPEC[target_node.name]["gpu_count"] > 0:
                            target_node.gpu_power_used += gpu_power
                            target_node.gpu_mem_used += gpu_mem
                        target_node.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                        target_node.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                        scheduled = True
                        successful_jobs += 1
                        break

            if not scheduled:
                # Job rejected (e.g., for AR/IM if no resources available)
                continue

    # Calculate energy consumption over 1 hour (60 minutes)
    total_time_minutes = 60
    for node in nodes:
        state_time = total_time_minutes  # Simplified: assume node stays in current state for entire period
        results["energy_consumption"] += node.get_power_consumption() * state_time

    results["job_success_rate"] = (successful_jobs / total_jobs) * 100 if total_jobs > 0 else 0
    results["active_hosts"] = len([n for n in nodes if n.state == "Active"])

    return results
    
# 1. Particle Swarm Optimization (PSO) for Job Scheduling
# particles：PSO 中的 粒子數 (Particles)，即候選解的數量，預設為 5
def pso_scheduling(nodes: List[Node], workload: pd.DataFrame, iterations: int = 10, particles: int = 5) -> Dict:
    results = {
        "energy_consumption": 0, 
        "job_success_rate": 0, 
        "active_hosts": 0,
        "node_states_over_time": {},  # 節點狀態隨時間變化的字典 {time: {node_name: state}}
        "cpu_load_over_time": {},     # CPU 負載隨時間變化的字典 {time: total_cpu_load}
        "energy_consumption_over_time": {}  # 能源消耗隨時間變化的字典 {time: total_energy}
    }
    total_jobs = 0
    successful_jobs = 0


    # Simplify PSO for job-node assignment (optimize for energy consumption)
    # 這個函式用來評估某個「粒子 (Particle)」的表現，根據：所有指派的工作是否能夠被執行、總體能耗的大小 (愈低愈好)
    def fitness(particle):  # Particle represents node assignments for jobs
        energy = 0
        for job_node in particle:
            node = nodes[job_node[1]]  # 取得對應的節點
            if node.can_handle_job(job_node[0][1], job_node[0][2], job_node[0][3]): # 檢查是否可執行
                energy += node.get_power_consumption()  # 計算能耗
        return -energy  # Minimize energy (negative for maximization in PSO) 負值：因為 PSO 會最大化適應度函數，而我們希望最小化能耗

    # Prepare jobs from workload
    jobs = []
    times = workload["hour"].unique()  # 獲取所有獨特時間點
    for idx, row in workload.iterrows():
        time = pd.to_datetime(row["hour"])  # 解析時間
        cpu_load = row["cpu_load"]
        gpu_power = row["gpu_power_usage"]
        gpu_mem = row["gpu_mem_used"]
        nodename = row["nodename"]
        classified_jobs = classify_jobs(cpu_load, JOB_DISTRIBUTION)  # 依 CPU 負載分類工作
        for job_type, load in classified_jobs:
            jobs.append((job_type, load, gpu_power, gpu_mem, time, nodename))  # 儲存工作資訊

    total_jobs = len(jobs)

    # Initialize time-series data 時間序列後新加的
    for time in times:
        results["node_states_over_time"][time] = {node.name: node.state for node in nodes}
        results["cpu_load_over_time"][time] = workload[workload["hour"] == time]["cpu_load"].sum()
        results["energy_consumption_over_time"][time] = 0  # 初始能源消耗為 0，後續更新



    # PSO initialization
    particle_positions = [[(job, random.randint(0, len(nodes)-1)) for job in jobs] for _ in range(particles)] # 每個粒子（候選解）包含一組「隨機的工作-節點分配方案」。
    particle_velocities = [[0 for _ in range(len(jobs))] for _ in range(particles)]  # 粒子的位置變化速度（初始化為 0）。
    personal_best = particle_positions.copy()   # 每個粒子找到的「最佳解」。
    personal_best_fitness = [fitness(p) for p in particle_positions]
    global_best = particle_positions[np.argmax(personal_best_fitness)]   # 全局最佳解，即所有粒子中最好的分配方案。
    global_best_fitness = max(personal_best_fitness)

    # PSO iterations 執行 PSO 迭代
    # 更新粒子位置，讓它根據「慣性因子、個體認知因子、社會影響因子」來調整解。
    # 計算新適應度值 (Fitness)，更新個體最優解 (personal_best) 和全域最優解 (global_best)。

    for _ in range(iterations):
        for i in range(particles):
            for j in range(len(jobs)):
                # Update velocity and position (simplified)
                inertia = 0.7
                cognitive = 0.5
                social = 0.5
                r1, r2 = random.random(), random.random()
                
                particle_velocities[i][j] = (inertia * particle_velocities[i][j] + 
                                            cognitive * r1 * (personal_best[i][j][1] - particle_positions[i][j][1]) + 
                                            social * r2 * (global_best[j][1] - particle_positions[i][j][1]))
                
                new_position = particle_positions[i][j][1] + particle_velocities[i][j]
                new_position = max(0, min(len(nodes)-1, int(new_position)))  # Ensure within bounds 確保在合法範圍內
                particle_positions[i][j] = (particle_positions[i][j][0], new_position)

            # Evaluate fitness  更新最佳解
            current_fitness = fitness(particle_positions[i])
            if current_fitness > personal_best_fitness[i]:
                personal_best[i] = particle_positions[i].copy()
                personal_best_fitness[i] = current_fitness
                if current_fitness > global_best_fitness:
                    global_best = particle_positions[i].copy()
                    global_best_fitness = current_fitness

    # Apply best solution  套用最佳解
    for job, node_idx in global_best:
        node = nodes[node_idx]
        if node.can_handle_job(job[1], job[2], job[3]):
            node.cpu_used += job[1]
            if NODE_SPEC[node.name]["gpu_count"] > 0:
                node.gpu_power_used += job[2]
                node.gpu_mem_used += job[3]
                
            node.update_state((job[4] - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, job[1])
            
            # job[4]job[4] ('IM', 13.716655, nan, nan, 'node-13') node-13
            print("job[4]job[4]", job, job[4]) # job[4] 是 node-167 不能轉成 to_datetime
            # node.update_state((pd.to_datetime(job[4]) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, job[1])
            # node.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
            node.available_time = (pd.to_datetime(job[4]) + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
            successful_jobs += 1
            
            # Update node state for this time
            """
            print('results["node_states_over_time"][time]', results["node_states_over_time"][time])
            print("node.state, node.name", node.state, node.name)

            results["node_states_over_time"][time] {'node-32': 'Active', 'node-11': 'Active', 'node-12': 'Active'...
            node.state, node.name Active node-19
            """

            results["node_states_over_time"][time][node.name] = node.state
            # Update energy consumption for this time
            results["energy_consumption_over_time"][time] += node.get_power_consumption()


    # Calculate final totals 有時間序列
    total_time_minutes = 60
    for time in times:
        for node in nodes:
            state_time = total_time_minutes if results["node_states_over_time"][time][node.name] == "Active" else 0
            results["energy_consumption"] += node.get_power_consumption() * state_time / len(times)  # Average over time points
            results["energy_consumption_over_time"][time] += node.get_power_consumption() * (state_time / len(times)) if results["node_states_over_time"][time][node.name] != "Idle" else 0

# 原本沒有時間序列的
    # for node in nodes:
    #     state_time = total_time_minutes
    #     results["energy_consumption"] += node.get_power_consumption() * state_time

    results["job_success_rate"] = (successful_jobs / total_jobs) * 100 if total_jobs > 0 else 0
    results["active_hosts"] = len([n for n in nodes if n.state == "Active"])

    return results

# 2. Round Robin (RR) Algorithm
def round_robin_scheduling(nodes: List[Node], workload: pd.DataFrame) -> Dict:
    results = {"energy_consumption": 0, "job_success_rate": 0, "active_hosts": 0}
    total_jobs = 0
    successful_jobs = 0

    # Prepare jobs and rotate through nodes
    jobs = []
    for idx, row in workload.iterrows():
        time = pd.to_datetime(row["hour"])
        cpu_load = row["cpu_load"]
        gpu_power = row["gpu_power_usage"]
        gpu_mem = row["gpu_mem_used"]
        nodename = row["nodename"]
        classified_jobs = classify_jobs(cpu_load, JOB_DISTRIBUTION)
        for job_type, load in classified_jobs:
            jobs.append((job_type, load, gpu_power, gpu_mem, time, nodename))

    total_jobs = len(jobs)
    node_idx = 0

    for job in jobs:
        job_type, load, gpu_power, gpu_mem, time, original_node = job
        # Cycle through nodes
        for _ in range(len(nodes)):
            if node_idx >= len(nodes):
                node_idx = 0
            node = nodes[node_idx]
            if node.can_handle_job(load, gpu_power, gpu_mem):
                node.cpu_used += load
                if NODE_SPEC[node.name]["gpu_count"] > 0:
                    node.gpu_power_used += gpu_power
                    node.gpu_mem_used += gpu_mem
                node.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                node.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                node.state = "Active"
                successful_jobs += 1
                break
            node_idx += 1
        else:
            # If no node can handle, try original node with preemption for AR/IM
            original_node_obj = next(n for n in nodes if n.name == original_node)
            if job_type in ["AR", "IM"] and original_node_obj.vm_queue and any(j[0] == "BE" for j in original_node_obj.vm_queue):
                original_node_obj.vm_queue = [j for j in original_node_obj.vm_queue if j[0] != "BE"]
                original_node_obj.cpu_used += load
                if NODE_SPEC[original_node_obj.name]["gpu_count"] > 0:
                    original_node_obj.gpu_power_used += gpu_power
                    original_node_obj.gpu_mem_used += gpu_mem
                original_node_obj.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                original_node_obj.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                successful_jobs += 1

    # Calculate energy consumption over 1 hour (60 minutes)
    total_time_minutes = 60
    for node in nodes:
        state_time = total_time_minutes
        results["energy_consumption"] += node.get_power_consumption() * state_time

    results["job_success_rate"] = (successful_jobs / total_jobs) * 100 if total_jobs > 0 else 0
    results["active_hosts"] = len([n for n in nodes if n.state == "Active"])

    return results

# 3. Shortest Job First (SJF) Algorithm
def sjf_scheduling(nodes: List[Node], workload: pd.DataFrame) -> Dict:
    results = {"energy_consumption": 0, "job_success_rate": 0, "active_hosts": 0}
    total_jobs = 0
    successful_jobs = 0

    # Prepare and sort jobs by CPU load (shortest first)
    jobs = []
    for idx, row in workload.iterrows():
        time = pd.to_datetime(row["hour"])
        cpu_load = row["cpu_load"]
        gpu_power = row["gpu_power_usage"]
        gpu_mem = row["gpu_mem_used"]
        nodename = row["nodename"]
        classified_jobs = classify_jobs(cpu_load, JOB_DISTRIBUTION)
        for job_type, load in classified_jobs:
            jobs.append((job_type, load, gpu_power, gpu_mem, time, nodename))

    total_jobs = len(jobs)
    jobs.sort(key=lambda x: x[1])  # Sort by CPU load (shortest job first)

    for job in jobs:
        job_type, load, gpu_power, gpu_mem, time, original_node = job
        # Try to schedule on any node with available resources
        for node in sorted(nodes, key=lambda x: x.available_time):
            if node.can_handle_job(load, gpu_power, gpu_mem):
                node.cpu_used += load
                if NODE_SPEC[node.name]["gpu_count"] > 0:
                    node.gpu_power_used += gpu_power
                    node.gpu_mem_used += gpu_mem
                node.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                node.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                node.state = "Active"
                successful_jobs += 1
                break
        else:
            # If no node can handle, try original node with preemption for AR/IM
            original_node_obj = next(n for n in nodes if n.name == original_node)
            if job_type in ["AR", "IM"] and original_node_obj.vm_queue and any(j[0] == "BE" for j in original_node_obj.vm_queue):
                original_node_obj.vm_queue = [j for j in original_node_obj.vm_queue if j[0] != "BE"]
                original_node_obj.cpu_used += load
                if NODE_SPEC[original_node_obj.name]["gpu_count"] > 0:
                    original_node_obj.gpu_power_used += gpu_power
                    original_node_obj.gpu_mem_used += gpu_mem
                original_node_obj.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                original_node_obj.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                successful_jobs += 1

    # Calculate energy consumption over 1 hour (60 minutes)
    total_time_minutes = 60
    for node in nodes:
        state_time = total_time_minutes
        results["energy_consumption"] += node.get_power_consumption() * state_time

    results["job_success_rate"] = (successful_jobs / total_jobs) * 100 if total_jobs > 0 else 0
    results["active_hosts"] = len([n for n in nodes if n.state == "Active"])

    return results

# 4. First Come First Serve (FCFS) Algorithm
def fcfs_scheduling(nodes: List[Node], workload: pd.DataFrame) -> Dict:
    results = {"energy_consumption": 0, "job_success_rate": 0, "active_hosts": 0}
    total_jobs = 0
    successful_jobs = 0

    # Prepare jobs in order of arrival (from workload)
    jobs = []
    for idx, row in workload.iterrows():
        time = pd.to_datetime(row["hour"])
        cpu_load = row["cpu_load"]
        gpu_power = row["gpu_power_usage"]
        gpu_mem = row["gpu_mem_used"]
        nodename = row["nodename"]
        classified_jobs = classify_jobs(cpu_load, JOB_DISTRIBUTION)
        for job_type, load in classified_jobs:
            jobs.append((job_type, load, gpu_power, gpu_mem, time, nodename))

    total_jobs = len(jobs)

    for job in jobs:
        job_type, load, gpu_power, gpu_mem, time, original_node = job
        # Try to schedule on the original node first, then any available node
        original_node_obj = next(n for n in nodes if n.name == original_node)
        if original_node_obj.can_handle_job(load, gpu_power, gpu_mem):
            original_node_obj.cpu_used += load
            if NODE_SPEC[original_node_obj.name]["gpu_count"] > 0:
                original_node_obj.gpu_power_used += gpu_power
                original_node_obj.gpu_mem_used += gpu_mem
            original_node_obj.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
            original_node_obj.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
            original_node_obj.state = "Active"
            successful_jobs += 1
        else:
            # Try other nodes in order of availability
            for node in sorted(nodes, key=lambda x: x.available_time):
                if node.can_handle_job(load, gpu_power, gpu_mem):
                    node.cpu_used += load
                    if NODE_SPEC[node.name]["gpu_count"] > 0:
                        node.gpu_power_used += gpu_power
                        node.gpu_mem_used += gpu_mem
                    node.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                    node.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                    node.state = "Active"
                    successful_jobs += 1
                    break
            else:
                # If no node can handle, try original node with preemption for AR/IM
                if job_type in ["AR", "IM"] and original_node_obj.vm_queue and any(j[0] == "BE" for j in original_node_obj.vm_queue):
                    original_node_obj.vm_queue = [j for j in original_node_obj.vm_queue if j[0] != "BE"]
                    original_node_obj.cpu_used += load
                    if NODE_SPEC[original_node_obj.name]["gpu_count"] > 0:
                        original_node_obj.gpu_power_used += gpu_power
                        original_node_obj.gpu_mem_used += gpu_mem
                    original_node_obj.update_state((time - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60, load)
                    original_node_obj.available_time = (time + timedelta(hours=1) - pd.Timestamp("2024-11-04 15:00:00")).total_seconds() / 60
                    successful_jobs += 1

    # Calculate energy consumption over 1 hour (60 minutes)
    total_time_minutes = 60
    for node in nodes:
        state_time = total_time_minutes
        results["energy_consumption"] += node.get_power_consumption() * state_time

    results["job_success_rate"] = (successful_jobs / total_jobs) * 100 if total_jobs > 0 else 0
    results["active_hosts"] = len([n for n in nodes if n.state == "Active"])

    return results

# Main execution to compare all algorithms
if __name__ == "__main__":
    # Initialize all nodes
    nodes = [Node(name) for name in NODE_SPEC.keys()]

#     # Load workload data (as provided in your previous message)
#     workload_data = [
#         # ... (保持您提供的 workload_data 内容，省略以节省空间，但确保完整)
#         {"hour": "2024-11-04 15:00:00", "nodename": "node-167", "cpu_load": 4.01083333333333, "cpu_alloc": 4.0, "cpu_idle": 0.0, "cpu_total": 4.0, "gpu_power_usage": 0.0, "gpu_mem_used": 0.0, "gpu_gpu_usage": 0.0, "gpu_fan": 0.0},
#         # ... (继续添加其他 workload 条目)
#         {"hour": "2024-11-04 16:00:00", "nodename": "node-165", "cpu_load": 4.00083333333333, "cpu_alloc": 4.0, "cpu_idle": 0.0, "cpu_total": 4.0, "gpu_power_usage": 0.0, "gpu_mem_used": 0.0, "gpu_gpu_usage": 0.0, "gpu_fan": 0.0}
#     ]
#     workload = pd.DataFrame(workload_data)

    # Run and compare all scheduling algorithms
    algorithms = {
        "EAVMAT": eavmat_scheduling,
        "PSO": pso_scheduling,
        "Round Robin": round_robin_scheduling,
        "SJF": sjf_scheduling,
        "FCFS": fcfs_scheduling
    }

    for name, algo in algorithms.items():
        # Reset node states before each algorithm run
        for node in nodes:
            node.reset_usage()
        
        results = algo(nodes.copy(), CPU_request_data[0:100])
        print(f"\n{name} Scheduling Results:")
        print(f"Total Energy Consumption (Watt-minutes): {results['energy_consumption']}")
        print(f"Job Success Rate (%): {results['job_success_rate']:.2f}")
        print(f"Number of Active Hosts: {results['active_hosts']}")

        # Optional: Print node states for this algorithm
        for node in nodes:
            if node.state == "Active":
                print(f"Node {node.name} - State: {node.state}, CPU Used: {node.cpu_used}, GPU Power Used: {node.gpu_power_used}, Power: {node.get_power_consumption()} Watts")
# Out:
# ffffu [<__main__.Node object at 0x15ae11a50>, <__main__.Node object at 0x1064d7450>, <__main__.Node object at 0x159701750>, <__main__.Node object at 0x1597019d0>, <__main__.Node object at 0x159f35450>, <__main__.Node object at 0x157654c90>, <__main__.Node object at 0x159691390>, <__main__.Node object at 0x159691310>, <__main__.Node object at 0x159692990>, <__main__.Node object at 0x157656850>, <__main__.Node object at 0x159666350>, <__main__.Node object at 0x1596652d0>, <__main__.Node object at 0x159666050>, <__main__.Node object at 0x1596667d0>, <__main__.Node object at 0x159666390>, <__main__.Node object at 0x159665e90>, <__main__.Node object at 0x1572b0410>, <__main__.Node object at 0x1572b1910>, <__main__.Node object at 0x1576d7c50>, <__main__.Node object at 0x1576d5350>, <__main__.Node object at 0x15a530c50>, <__main__.Node object at 0x1576ecdd0>, <__main__.Node object at 0x1576ef090>, <__main__.Node object at 0x15a89d490>, <__main__.Node object at 0x156564d10>, <__main__.Node object at 0x1571e6710>, <__main__.Node object at 0x1571e5810>, <__main__.Node object at 0x1571e4990>, <__main__.Node object at 0x1571e5990>, <__main__.Node object at 0x1571e7c90>, <__main__.Node object at 0x1571e62d0>, <__main__.Node object at 0x1571e5c10>, <__main__.Node object at 0x1571e4590>, <__main__.Node object at 0x1571e5b50>, <__main__.Node object at 0x1571e5150>]                    hour  nodename   cpu_load  cpu_alloc  cpu_idle  cpu_total  \
# 0   2024-11-04 14:00:00   node-14  95.110000       95.0       1.0       96.0
# 1   2024-11-04 14:00:00   node-13  44.105000       44.0       0.0       44.0
# 2   2024-11-04 14:00:00   node-32  18.680000       30.0       2.0       32.0
# 3   2024-11-04 14:00:00   node-19   5.000000        5.0      75.0       80.0
# 4   2024-11-04 14:00:00   node-18  28.040000       36.0       0.0       36.0
# ..                  ...       ...        ...        ...       ...        ...
# 95  2024-11-04 18:00:00  node-162   4.045833        4.0       0.0        4.0
# 96  2024-11-04 18:00:00   node-11  44.332500       44.0       0.0       44.0
# 97  2024-11-04 18:00:00   node-12  44.130000       44.0       0.0       44.0
# 98  2024-11-04 18:00:00   node-13  44.200833       44.0       0.0       44.0
# 99  2024-11-04 18:00:00  node-165   4.018333        4.0       0.0        4.0
#
#     gpu_power_usage  gpu_mem_used  gpu_gpu_usage  gpu_fan
# 0               NaN           NaN            NaN      NaN
# 1               NaN           NaN            NaN      NaN
# 2         98.162500      7270.375        14.5625      0.0
# 3               NaN           NaN            NaN      NaN
# 4               NaN           NaN            NaN      NaN
# ..              ...           ...            ...      ...
# 95       114.566667      7397.000        31.0000      0.0
# 96              NaN           NaN            NaN      NaN
# 97              NaN           NaN            NaN      NaN
# 98              NaN           NaN            NaN      NaN
# 99              NaN           NaN            NaN      NaN
#
# [100 rows x 10 columns]
# nodenamenodename node-14
# jobsjobs [('AR', 19.9731), ('IM', 27.962339999999998), ('BE', 47.17456)]
# nodenamenodename node-13
# jobsjobs [('AR', 8.37995), ('IM', 12.790449999999998), ('BE', 22.9346)]
# nodenamenodename node-32
# jobsjobs [('AR', 3.47448), ('IM', 5.99628), ('BE', 9.20924)]
# nodenamenodename node-19
# jobsjobs [('AR', 1.085), ('IM', 1.44), ('BE', 2.475)]
# nodenamenodename node-18
# jobsjobs [('AR', 6.22488), ('IM', 8.15964), ('BE', 13.655479999999999)]
# nodenamenodename node-172
# nodenamenodename node-171
# nodenamenodename node-17
# jobsjobs [('AR', 6.3), ('IM', 11.448), ('BE', 18.252)]
# nodenamenodename node-168
# jobsjobs [('AR', 0.22344999999999998), ('IM', 0.312625), ('BE', 0.48892499999999994)]
# nodenamenodename node-12
# jobsjobs [('AR', 8.553460000000001), ('IM', 13.13882), ('BE', 22.397720000000003)]
# nodenamenodename node-141
# jobsjobs [('AR', 0.208), ('IM', 0.324), ('BE', 0.468)]
# nodenamenodename node-167
# jobsjobs [('AR', 0.712), ('IM', 1.212), ('BE', 2.076)]
# nodenamenodename node-166
# jobsjobs [('AR', 0.21725999999999998), ('IM', 0.31737), ('BE', 0.53037)]
# nodenamenodename node-165
# jobsjobs [('AR', 0.813015), ('IM', 1.1214000000000002), ('BE', 2.070585)]
# nodenamenodename node-164
# jobsjobs [('AR', 0.21008000000000002), ('IM', 0.312), ('BE', 0.51792)]
# nodenamenodename node-163
# jobsjobs [('AR', 0.81702), ('IM', 1.1774699999999998), ('BE', 2.01051)]
# nodenamenodename node-162
# jobsjobs [('AR', 0.6513), ('IM', 1.0187), ('BE', 1.67)]
# nodenamenodename node-161
# jobsjobs [('AR', 0.79596), ('IM', 1.1818799999999998), ('BE', 2.04216)]
# nodenamenodename node-16
# nodenamenodename node-11
# jobsjobs [('AR', 9.08769), ('IM', 12.396315000000001), ('BE', 22.630995000000002)]
# nodenamenodename node-15
# jobsjobs [('AR', 0
Power: 2200 Watts
# Node node-155 - State: Active, CPU Used: 0.0075608333333333265, GPU Power Used: 0.07560833333333326, Power: 2200 Watts
# Node node-156 - State: Active, CPU Used: 2.2912866666666667, GPU Power Used: 0, Power: 2200 Watts
# Node node-157 - State: Active, CPU Used: 0.010606666666666657, GPU Power Used: 0, Power: 2200 Watts
# Node node-158 - State: Active, CPU Used: 0.017665833333333318, GPU Power Used: 0.1766583333333332, Power: 2200 Watts
# Node esxi-34 - State: Active, CPU Used: 0.7802666666666666, GPU Power Used: 7.802666666666665, Power: 4400 Watts
# Node node-161 - State: Active, CPU Used: 0.5088, GPU Power Used: 5.088, Power: 2200 Watts
# Node node-162 - State: Active, CPU Used: 0.6513, GPU Power Used: 6.513, Power: 2200 Watts
# Node node-163 - State: Active, CPU Used: 1.9412125000000002, GPU Power Used: 0, Power: 2200 Watts
# Node node-164 - State: Active, CPU Used: 0.5282016666666667, GPU Power Used: 5.282016666666667, Power: 2200 Watts
# Node node-165 - State: Active, CPU Used: 2.0413133333333335, GPU Power Used: 0, Power: 2200 Watts
# Node node-166 - State: Active, CPU Used: 0.5187558333333334, GPU Power Used: 5.187558333333334, Power: 2200 Watts
# Node node-167 - State: Active, CPU Used: 2.1029866666666663, GPU Power Used: 0, Power: 2200 Watts
# Node node-168 - State: Active, CPU Used: 0.5163625, GPU Power Used: 5.163625, Power: 2200 Watts
# Node esxi-35 - State: Active, CPU Used: 1.1386666666666665, GPU Power Used: 11.386666666666665, Power: 3200 Watts
# Node node-141 - State: Active, CPU Used: 0.49587583333333335, GPU Power Used: 4.958758333333334, Power: 1600 Watts
# Node esxi-36 - State: Active, CPU Used: 1.8143999999999998, GPU Power Used: 18.144, Power: 2400 Watts
# Node node-171 - State: Active, CPU Used: 0.001, GPU Power Used: 0.01, Power: 2400 Watts
# Node node-172 - State: Active, CPU Used: 0.001, GPU Power Used: 0.01, Power: 2400 Watts
# Node esxi-37 - State: Active, CPU Used: 0.8415333333333334, GPU Power Used: 8.415333333333333, Power: 2400 Watts
# jobsjobs [('AR', 18.54645), ('IM', 27.962339999999998), ('BE', 48.60121)]
# jobsjobs [('AR', 8.64458), ('IM', 12.834554999999998), ('BE', 22.625864999999997)]
# jobsjobs [('AR', 4.05356), ('IM', 5.28644), ('BE', 9.34)]
# jobsjobs [('AR', 1.055), ('IM', 1.3450000000000002), ('BE', 2.6)]
# jobsjobs [('AR', 4.73876), ('IM', 8.80456), ('BE', 14.49668)]
# jobsjobs [('AR', 7.776), ('IM', 10.223999999999998), ('BE', 18.0)]
# jobsjobs [('AR', 0.208075), ('IM', 0.30339999999999995), ('BE', 0.513525)]
# jobsjobs [('AR', 8.3771), ('IM', 13.44745), ('BE', 22.26545)]
# jobsjobs [('AR', 0.222), ('IM', 0.293), ('BE', 0.485)]
# jobsjobs [('AR', 0.804), ('IM', 1.268), ('BE', 1.928)]
# jobsjobs [('AR', 0.211935), ('IM', 0.286485), ('BE', 0.56658)]
# jobsjobs [('AR', 0.893115), ('IM', 1.1854799999999999), ('BE', 1.926405)]
# jobsjobs [('AR', 0.20592000000000002), ('IM', 0.2912), ('BE', 0.54288)]
# jobsjobs [('AR', 0.756945), ('IM', 1.2335399999999999), ('BE', 2.014515)]
# jobsjobs [('AR', 0.6947199999999999), ('IM', 1.0521), ('BE', 1.5931799999999998)]
# jobsjobs [('AR', 0.9326399999999999), ('IM', 1.1416799999999998), ('BE', 1.9456799999999996)]
# jobsjobs [('AR', 8.161275), ('IM', 13.543305), ('BE', 22.410420000000002)]
# jobsjobs [('AR', 0.018059999999999996), ('IM', 0.031814999999999996), ('BE', 0.055125)]
# jobsjobs [('AR', 0.842275), ('IM', 1.227315), ('BE', 1.9412433333333332)]
# jobsjobs [('AR', 0.1995933333333333), ('IM', 0.3207749999999999), ('BE', 0.4979649999999999)]
# jobsjobs [('AR', 0.9771125), ('IM', 1.5734016666666666), ('BE', 2.4603191666666664)]
# jobsjobs [('AR', 0.001), ('IM', 0.001), ('BE', 0.001)]
# jobsjobs [('AR', 5
 2024-11-04 18:00:00
# job[4]job[4] ('BE', 11.812690833333331, 73.69010416666667, 9017.0, Timestamp('2024-11-04 18:00:00'), 'node-32') 2024-11-04 18:00:00
# job[4]job[4] ('AR', 0.21333333333333337, 56.3175, 297.0, Timestamp('2024-11-04 18:00:00'), 'node-161') 2024-11-04 18:00:00
# job[4]job[4] ('IM', 0.3221333333333334, 56.3175, 297.0, Timestamp('2024-11-04 18:00:00'), 'node-161') 2024-11-04 18:00:00
# job[4]job[4] ('BE', 0.5312000000000001, 56.3175, 297.0, Timestamp('2024-11-04 18:00:00'), 'node-161') 2024-11-04 18:00:00
# job[4]job[4] ('IM', 1.0397791666666667, 114.56666666666666, 7397.0, Timestamp('2024-11-04 18:00:00'), 'node-162') 2024-11-04 18:00:00
# job[4]job[4] ('BE', 21.811590000000002, nan, nan, Timestamp('2024-11-04 18:00:00'), 'node-11') 2024-11-04 18:00:00
# job[4]job[4] ('AR', 9.664470000000001, nan, nan, Timestamp('2024-11-04 18:00:00'), 'node-12') 2024-11-04 18:00:00
# job[4]job[4] ('AR', 8.707564166666666, nan, nan, Timestamp('2024-11-04 18:00:00'), 'node-13') 2024-11-04 18:00:00
#
# PSO Scheduling Results:
# Total Energy Consumption (Watt-minutes): 1089600.0
# Job Success Rate (%): 58.51
# Number of Active Hosts: 35
# Node node-32 - State: Active, CPU Used: 0.22578833333333334, GPU Power Used: 2.2578833333333335, Power: 4400 Watts
# Node node-11 - State: Active, CPU Used: 15.616001666666664, GPU Power Used: 0, Power: 2200 Watts
# Node node-12 - State: Active, CPU Used: 8.707564166666666, GPU Power Used: 0, Power: 2200 Watts
# Node node-13 - State: Active, CPU Used: 41.05616666666667, GPU Power Used: 0, Power: 2200 Watts
# Node node-14 - State: Active, CPU Used: 9.664470000000001, GPU Power Used: 0, Power: 2200 Watts
# Node esxi-31 - State: Active, CPU Used: 0.001, GPU Power Used: 0.01, Power: 3200 Watts
# Node node-15 - State: Active, CPU Used: 0.5948025, GPU Power Used: 5.948025, Power: 1600 Watts
# Node node-16 - State: Active, CPU Used: 1.20675, GPU Power Used: 12.067499999999999, Power: 1600 Watts
# Node node-17 - State: Active, CPU Used: 0.3220566666666667, GPU Power Used: 0, Power: 3200 Watts
# Node node-18 - State: Active, CPU Used: 1.3048150000000003, GPU Power Used: 0, Power: 3200 Watts
# Node node-19 - State: Active, CPU Used: 0.26411666666666667, GPU Power Used: 0, Power: 6400 Watts
# Node esxi-33 - State: Active, CPU Used: 0.286485, GPU Power Used: 2.8648499999999997, Power: 4400 Watts
# Node node-151 - State: Active, CPU Used: 21.811590000000002, GPU Power Used: 0, Power: 2200 Watts
# Node node-152 - State: Active, CPU Used: 12.389506666666666, GPU Power Used: 123.89506666666665, Power: 2200 Watts
# Node node-153 - State: Active, CPU Used: 0.3221333333333334, GPU Power Used: 3.221333333333334, Power: 2200 Watts
# Node node-154 - State: Active, CPU Used: 0.485, GPU Power Used: 4.85, Power: 2200 Watts
# Node node-155 - State: Active, CPU Used: 11.812690833333331, GPU Power Used: 118.12690833333332, Power: 2200 Watts
# Node node-156 - State: Active, CPU Used: 7.4038974999999985, GPU Power Used: 0, Power: 2200 Watts
# Node node-157 - State: Active, CPU Used: 1.0397791666666667, GPU Power Used: 0, Power: 2200 Watts
# Node node-158 - State: Active, CPU Used: 0.018059999999999982, GPU Power Used: 0.18059999999999982, Power: 2200 Watts
# Node esxi-34 - State: Active, CPU Used: 1.0154666666666667, GPU Power Used: 10.154666666666667, Power: 4400 Watts
# Node node-161 - State: Active, CPU Used: 0.002933333333333312, GPU Power Used: 0.02933333333333312, Power: 2200 Watts
# Node node-162 - State: Active, CPU Used: 4.05356, GPU Power Used: 40.5356, Power: 2200 Watts
# Node node-163 - State: Active, CPU Used: 0.8307599999999998, GPU Power Used: 0, Power: 2200 Watts
# Node node-164 - State: Active, CPU Used: 0.5404233333333334, GPU Power Used: 5.404233333333334, Power: 2200 Watts
# Node node-165 - State: Active, CPU Used: 0.5312000000000001, GPU Power Used: 0, Power: 2200 Watts
# Node node-166 - State: Active, CPU Used: 14.003014166666668, GPU Power Used: 140.03014166666668, Power: 2200 Watts
# Node node-167 - State: Active, CPU Used: 0.29424, GPU Power Used: 0, Power: 2200 Watts
# Node node-168 - State: Active, CPU Used: 0.21333333333333337, GPU Power Used: 2.1333333333333337, Power: 2200 Watts
# Node esxi-35 - State: Active, CPU Used: 0.4979649999999999, GPU Power Used: 4.979649999999999, Power: 3200 Watts
# ...
# jobsjobs [('AR', 15.396062500000001), ('IM', 24.475791666666666), ('BE', 39.0823125)]
# jobsjobs [('AR', 0.2033116666666667), ('IM', 0.3065), ('BE', 0.5118550000000001)]
# jobsjobs [('AR', 0.7524700000000001), ('IM', 1.2527825000000001), ('BE', 1.9972475000000003)]
# jobsjobs [('AR', 5.007814166666666), ('IM', 7.667466666666666), ('BE', 11.285552499999998)]
# jobsjobs [('AR', 0.20800000000000005), ('IM', 0.3114666666666667), ('BE', 0.5472000000000001)]
# jobsjobs [('AR', 0.8172583333333334), ('IM', 1.140925), ('BE', 2.08765)]
# jobsjobs [('AR', 8.8221675), ('IM', 13.211085), ('BE', 22.299247500000003)]
# jobsjobs [('AR', 8.428830000000001), ('IM', 12.312270000000002), ('BE', 23.388900000000003)]
# jobsjobs [('AR', 8.972769166666666), ('IM', 13.613856666666665), ('BE', 21.614207499999996)]
# jobsjobs [('AR', 0.8599233333333334), ('IM', 1.1894266666666666), ('BE', 1.9689833333333333)]
#
# SJF Scheduling Results:
# Total Energy Consumption (Watt-minutes): 5448000
# Job Success Rate (%): 100.00
# Number of Active Hosts: 35
# Node node-32 - State: Active, CPU Used: 0.194275, GPU Power Used: 1.94275, Power: 4400 Watts
# Node node-11 - State: Active, CPU Used: 47.44200916666667, GPU Power Used: 0, Power: 2200 Watts
# Node node-12 - State: Active, CPU Used: 0.8267466666666665, GPU Power Used: 0, Power: 2200 Watts
# Node node-13 - State: Active, CPU Used: 0.8599233333333334, GPU Power Used: 0, Power: 2200 Watts
# Node node-14 - State: Active, CPU Used: 0.3065, GPU Power Used: 0, Power: 2200 Watts
# Node esxi-31 - State: Active, CPU Used: 0.3114666666666667, GPU Power Used: 3.1146666666666674, Power: 3200 Watts
# Node node-15 - State: Active, CPU Used: 0.2033116666666667, GPU Power Used: 2.033116666666667, Power: 1600 Watts
# Node node-16 - State: Active, CPU Used: 2.1229649999999998, GPU Power Used: 21.22965, Power: 1600 Watts
# Node node-17 - State: Active, CPU Used: 1.140925, GPU Power Used: 0, Power: 3200 Watts
# Node node-18 - State: Active, CPU Used: 1.1894266666666666, GPU Power Used: 0, Power: 3200 Watts
# Node node-19 - State: Active, CPU Used: 1.2280799999999998, GPU Power Used: 0, Power: 6400 Watts
# Node esxi-33 - State: Active, CPU Used: 5.007814166666666, GPU Power Used: 50.07814166666666, Power: 4400 Watts
# Node node-151 - State: Active, CPU Used: 1.2527825000000001, GPU Power Used: 0, Power: 2200 Watts
# Node node-152 - State: Active, CPU Used: 7.667466666666666, GPU Power Used: 76.67466666666667, Power: 2200 Watts
# Node node-153 - State: Active, CPU Used: 0.001, GPU Power Used: 0.01, Power: 2200 Watts
# Node node-154 - State: Active, CPU Used: 0.001, GPU Power Used: 0.01, Power: 2200 Watts
# Node node-155 - State: Active, CPU Used: 0.4896316666666667, GPU Power Used: 4.896316666666667, Power: 2200 Watts
# Node node-156 - State: Active, CPU Used: 1.9585066666666664, GPU Power Used: 0, Power: 2200 Watts
# Node node-157 - State: Active, CPU Used: 1.9689833333333333, GPU Power Used: 0, Power: 2200 Watts
# Node node-158 - State: Active, CPU Used: 0.5108333333333334, GPU Power Used: 5.108333333333333, Power: 2200 Watts
# Node esxi-34 - State: Active, CPU Used: 0.20485250000000002, GPU Power Used: 2.048525, Power: 4400 Watts
# Node node-161 - State: Active, CPU Used: 0.5118550000000001, GPU Power Used: 5.118550000000001, Power: 2200 Watts
# Node node-162 - State: Active, CPU Used: 0.529655, GPU Power Used: 5.29655, Power: 2200 Watts
# Node node-163 - State: Active, CPU Used: 0.5472000000000001, GPU Power Used: 0, Power: 2200 Watts
# Node node-164 - State: Active, CPU Used: 0.20800000000000005, GPU Power Used: 2.0800000000000005, Power: 2200 Watts
# Node node-165 - State: Active, CPU Used: 1.9972475000000003, GPU Power Used: 0, Power: 2200 Watts
# Node node-166 - State: Active, CPU Used: 0.5780474999999999, GPU Power Used: 5.780474999999999, Power: 2200 Watts
# Node node-167 - State: Active, CPU Used: 0.7524700000000001, GPU Power Used: 0, Power: 2200 Watts
# Node node-168 - State: Active, CPU Used: 0.010929166666666656, GPU Power Used: 0.10929166666666656, Power: 2200 Watts
# Node esxi-35 - State: Active, CPU Used: 0.29856999999999995, GPU Power Used: 2.9856999999999996, Power: 3200 Watts
# Node node-141 - State: Active, CPU Used: 0.8321649999999999, GPU Power Used: 8.32165, Power: 1600 Watts
# Node esxi-36 - State: Active, CPU Used: 0.017844999999999982, GPU Power Used: 0.17844999999999983, Power: 2400 Watts
# Node node-171 - State: Active, CPU Used: 2.003205, GPU Power Used: 20.032049999999998, Power: 2400 Watts
# Node node-172 - State: Active, CPU Used: 0.17675, GPU Power Used: 1.7674999999999998, Power: 2400 Watts
# Node esxi-37 - State: Active, CPU Used: 0.3047675, GPU Power Used: 3.0476750000000004, Power: 2400 Watts
# jobsjobs [('AR', 18.92689), ('IM', 27.86723), ('BE', 48.31588)]
# jobsjobs [('AR', 8.115319999999999), ('IM', 13.496129999999999), ('BE', 22.49355)]
# jobsjobs [('AR', 3.28768), ('IM', 5.67872), ('BE', 9.7136)]
# jobsjobs [('AR', 0.9199999999999999), ('IM', 1.52), ('BE', 2.56)]
# jobsjobs [('AR', 5.4678), ('IM', 8.047479999999998), ('BE', 14.52472)]
# jobsjobs [('AR', 7.524), ('IM', 10.728), ('BE', 17.748)]
# jobsjobs [('AR', 0.2009), ('IM', 0.29929999999999995), ('BE', 0.5247999999999999)]
# jobsjobs [('AR', 9.567530000000001), ('IM', 13.09473), ('BE', 21.42774)]
# jobsjobs [('AR', 0.195), ('IM', 0.317), ('BE', 0.488)]
# jobsjobs [('AR', 0.7), ('IM', 1.288), ('BE', 2.012)]
# jobsjobs [('AR', 0.21725999999999998), ('IM', 0.33866999999999997), ('BE', 0.5090699999999999)]
# jobsjobs [('AR', 0.813015), ('IM', 1.1534399999999998), ('BE', 2.038545)]
# jobsjobs [('AR', 0.20176000000000002), ('IM', 0.3172), ('BE', 0.5210400000000001)]
# jobsjobs [('AR', 0.80901), ('IM', 1.173465), ('BE', 2.022525)]
# jobsjobs [('AR', 0.59786), ('IM', 1.04876), ('BE', 1.6933799999999999)]
# jobsjobs [('AR', 0.8642999999999998), ('IM', 1.2019799999999998), ('BE', 1.9537199999999997)]
# jobsjobs [('AR', 9.35238), ('IM', 12.572775), ('BE', 22.189845000000002)]
# jobsjobs [('AR', 0.018375), ('IM', 0.033075), ('BE', 0.05355)]
# jobsjobs [('AR', 0.77008), ('IM', 1.2594016666666668), ('BE', 1.9813516666666666)]
# jobsjobs [('AR', 0.18228166666666662), ('IM', 0.3228116666666666), ('BE', 0.5132399999999999)]
# jobsjobs [('AR', 1.0673074999999999), ('IM', 1.5433366666666666), ('BE', 2.4001891666666664)]
# jobsjobs [('AR', 0.001), ('IM', 0.001), ('BE', 0.001)]
# jobsjobs [('AR', 5.432808333333333), ('IM', 8.877320833333332), ('BE', 13.694037499999999)]
# jobsjobs [('AR', 0.2198375), ('IM', 0.30266), ('BE', 0.5000025)]
# jobsjobs [('AR', 7.308000000000001), ('IM', 10.511999999999999), ('BE', 18.18)]
# jobsjobs [('AR', 0.8126766666666666), ('IM', 1.0809), ('BE', 2.1097566666666667)]
# jobsjobs [('AR', 0.001), ('IM', 0.001), ('BE', 0.001)]
# jobsjobs [('AR', 0.7864500000000001), ('IM', 1.1596125), ('BE', 2.0664375)]
# jobsjobs [('AR', 0.7490383333333333), ('IM', 1.2870216666666665), ('BE', 2.102273333333333)]
# jobsjobs [('AR', 0.844725), ('IM', 1.1303225000000001), ('BE', 2.0474525)]
# jobsjobs [('AR', 0.004549999999999982), ('IM', 0.007674999999999969), ('BE', 0.01277499999999995)]
# jobsjobs [('AR', 0.2026666666666667), ('IM', 0.3121066666666667), ('BE', 0.49856000000000006)]
# jobsjobs [('AR', 18.164895833333336), ('IM', 30.33822916666667), ('BE', 46.601041666666674)]
# jobsjobs [('AR', 9.266599999999999), ('IM', 14.076406666666667), ('BE', 20.783659999999998)]
# jobsjobs [('AR', 5.7890175), ('IM', 8.32338), ('BE', 12.565102499999998)]
# jobsjobs [('AR', 8.2518425), ('IM', 13.326505), ('BE', 22.549152499999998)]
# jobsjobs [('AR', 0.22199666666666662), ('IM', 0.3044816666666666), ('BE', 0.4918549999999999)]
# jobsjobs [('AR', 8.78585), ('IM', 13.245), ('BE', 22.119149999999998)]
# jobsjobs [('AR', 0.001), ('IM', 0.0012749999999999795), ('BE', 0.0020624999999999667)]
# jobsjobs [('AR', 0.76912), ('IM', 1.1176275000000002), ('BE', 2.1190858333333336)]
# jobsjobs [('AR', 5.6947425), ('IM', 7.950630833333334), ('BE', 13.865460000000002)]
# jobsjobs [('AR', 7.555624999999999), ('IM', 13.4706), ('BE', 22.148775)]
# jobsjobs [('AR', 5.4634125), ('IM', 8.9936175), ('BE', 13.560469999999999)]
# jobsjobs [('AR', 0.001), ('IM', 0.001), ('BE', 0.001)]
# jobsjobs [('AR', 0
# jobsjobs [('AR', 0.206545), ('IM', 0.27403), ('BE', 0.541925)]
# jobsjobs [('AR', 0.8387866666666665), ('IM', 1.1518266666666663), ('BE', 2.0227199999999996)]
# jobsjobs [('AR', 5.392177499999999), ('IM', 8.023143333333332), ('BE', 12.633845833333332)]
# jobsjobs [('AR', 15.790833333333333), ('IM', 25.58115), ('BE', 37.58218333333333)]
# jobsjobs [('AR', 0.20637666666666668), ('IM', 0.3105866666666667), ('BE', 0.5047033333333334)]
# jobsjobs [('AR', 0.7644775), ('IM', 1.2687925000000002), ('BE', 1.9692300000000003)]
# jobsjobs [('AR', 4.768205833333333), ('IM', 7.212210833333332), ('BE', 11.980416666666665)]
# jobsjobs [('AR', 0.22720000000000004), ('IM', 0.31360000000000005), ('BE', 0.5258666666666668)]
# jobsjobs [('AR', 0.7848916666666667), ('IM', 1.1975666666666667), ('BE', 2.063375)]
# jobsjobs [('AR', 9.1768275), ('IM', 12.679095), ('BE', 22.4765775)]
# jobsjobs [('AR', 8.958390000000001), ('IM', 14.1216), ('BE', 21.05001)]
# jobsjobs [('AR', 9.6799825), ('IM', 12.862442499999998), ('BE', 21.65840833333333)]
# jobsjobs [('AR', 0.7514283333333334), ('IM', 1.1653166666666666), ('BE', 2.1015883333333334)]
#
# FCFS Scheduling Results:
# Total Energy Consumption (Watt-minutes): 5448000
# Job Success Rate (%): 100.00
# Number of Active Hosts: 35
# Node node-32 - State: Active, CPU Used: 11.980416666666665, GPU Power Used: 119.80416666666665, Power: 4400 Watts
# Node node-11 - State: Active, CPU Used: 22.4765775, GPU Power Used: 0, Power: 2200 Watts
# Node node-12 - State: Active, CPU Used: 21.05001, GPU Power Used: 0, Power: 2200 Watts
# Node node-13 - State: Active, CPU Used: 21.65840833333333, GPU Power Used: 0, Power: 2200 Watts
# Node node-14 - State: Active, CPU Used: 47.35648666666667, GPU Power Used: 0, Power: 2200 Watts
# Node esxi-31 - State: Active, CPU Used: 1.1975666666666667, GPU Power Used: 11.975666666666667, Power: 3200 Watts
# Node node-15 - State: Active, CPU Used: 0.033075, GPU Power Used: 0.33075, Power: 1600 Watts
# Node node-16 - State: Active, CPU Used: 0.001, GPU Power Used: 0.01, Power: 1600 Watts
# Node node-17 - State: Active, CPU Used: 18.648431666666667, GPU Power Used: 0, Power: 3200 Watts
# Node node-18 - State: Active, CPU Used: 12.633845833333332, GPU Power Used: 0, Power: 3200 Watts
# Node node-19 - State: Active, CPU Used: 37.58218333333333, GPU Power Used: 0, Power: 6400 Watts
# Node esxi-33 - State: Active, CPU Used: 2.063375, GPU Power Used: 20.633750000000003, Power: 4400 Watts
# Node node-151 - State: Active, CPU Used: 1.291613333333333, GPU Power Used: 0, Power: 2200 Watts
# Node node-152 - State: Active, CPU Used: 0.007999999999999988, GPU Power Used: 0.07999999999999988, Power: 2200 Watts
# Node node-153 - State: Active, CPU Used: 0.01299999999999998, GPU Power Used: 0.1299999999999998, Power: 2200 Watts
# Node node-154 - State: Active, CPU Used: 0.020666666666666635, GPU Power Used: 0.20666666666666636, Power: 2200 Watts
# Node node-155 - State: Active, CPU Used: 0.007345833333333326, GPU Power Used: 0.07345833333333326, Power: 2200 Watts
# Node node-156 - State: Active, CPU Used: 2.167433333333333, GPU Power Used: 0, Power: 2200 Watts
# Node node-157 - State: Active, CPU Used: 0.011323333333333322, GPU Power Used: 0, Power: 2200 Watts
# Node node-158 - State: Active, CPU Used: 0.01716416666666665, GPU Power Used: 0.1716416666666665, Power: 2200 Watts
# Node esxi-34 - State: Active, CPU Used: 0.6943999999999999, GPU Power Used: 6.943999999999999, Power: 4400 Watts
# Node node-161 - State: Active, CPU Used: 0.5258666666666668, GPU Power Used: 5.258666666666668, Power: 2200 Watts
# Node node-162 - State: Active, CPU Used: 0.59786, GPU Power Used: 5.978599999999999, Power: 2200 Watts
# Node node-163 - State: Active, CPU Used: 1.9692300000000003, GPU Power Used: 0, Power: 2200 Watts
# Node node-164 - State: Active, CPU Used: 0.5047033333333334, GPU Power Used: 5.047033333333334, Power: 2200 Watts
# Node node-165 - State: Active, CPU Used: 2.1015883333333334, GPU Power Used: 0, Power: 2200 Watts
# Node node-166 - State: Active, CPU Used: 0.4810466666666667, GPU Power Used: 4.810466666666667, Power: 2200 Watts
# Node node-167 - State: Active, CPU Used: 2.0227199999999996, GPU Power Used: 0, Power: 2200 Watts
# Node node-168 - State: Active, CPU Used: 0.541925, GPU Power Used: 5.41925, Power: 2200 Watts
# Node esxi-35 - State: Active, CPU Used: 1.1050666666666664, GPU Power Used: 11.050666666666665, Power: 3200 Watts
# Node node-141 - State: Active, CPU Used: 0.47073000000000004, GPU Power Used: 4.7073, Power: 1600 Watts
# Node esxi-36 - State: Active, CPU Used: 1.9338666666666666, GPU Power Used: 19.338666666666665, Power: 2400 Watts
# Node node-171 - State: Active, CPU Used: 0.001, GPU Power Used: 0.01, Power: 2400 Watts
# Node node-172 - State: Active, CPU Used: 0.001, GPU Power Used: 0.01, Power: 2400 Watts
# Node esxi-37 - State: Active, CPU Used: 0.7848916666666667, GPU Power Used: 7.848916666666667, Power: 2400 Watts
